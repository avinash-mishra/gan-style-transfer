# %%
import torch
import os
from subprocess import Popen, PIPE
import shlex

from IPython.display import Image
from IPython.display import display

# %%
# define the path to the working directory
experiment_dir = 'github/PyTorch-Multi-Style-Transfer/experiments'
workingdir = '{}/{}'.format(os.environ['HOME'], experiment_dir)

# %%
# specify the path to the main.py script
path2script = '{}/main.py'.format(workingdir)

# specify the list of arguments to be used as input to main.py
args = ['eval',
        '--content-image',
        '{}/images/content/venice-boat.jpg'.format(workingdir),
        '--style-image',
        '{}/images/21styles/starry_night.jpg'.format(workingdir),
        '--model',
        '{}/models/21styles.model'.format(workingdir),
        '--output-image',
        '{}/test.jpg'.format(workingdir),
        '--cuda=0']

# %%
display(workingdir)
display(path2script)
# Out:
# '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments'
# '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/main.py'

# %%
content_image = Image('{}/images/content/venice-boat.jpg'.format(workingdir))
style_image = Image('{}/images/21styles/starry_night.jpg'.format(workingdir))
display(content_image)
display(style_image)

# %%
# build subprocess command
cmd = ['python3', path2script] + args

# run the command
# x = subprocess.check_output(cmd, universal_newlines=True)

display(cmd)
# Out:
# ['python3',
#  '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/main.py',
#  'eval',
#  '--content-image',
#  '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/images/content/venice-boat.jpg',
#  '--style-image',
#  '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/images/21styles/starry_night.jpg',
#  '--model',
#  '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/models/21styles.model',
#  '--output-image',
#  '/Users/avinash/github/PyTorch-Multi-Style-Transfer/experiments/test.jpg',
#  '--cuda=0']

# %%
def execute_in_virtualenv(virtualenv_name, commands):
    '''Execute Python code in a virtualenv, return its stdout and stderr.'''
    command_template = '/bin/bash -c "source {}/{}/bin/activate && python -"'
    command = shlex.split(command_template.format(os.environ['WORKON_HOME'],
                                                  virtualenv_name))
    process = Popen(command, stdin=PIPE, stdout=PIPE, stderr=PIPE, shell=False)
    return process.communicate(commands)

# %%
# run the command

x = subprocess.Popen(["/Users/avinash/anaconda3/envs/venv_py3.6/bin/python3.6", cmd])

# x = subprocess.check_output(cmd, universal_newlines=True)
# y = subprocess.check_output(f'source activate ~/anaconda/envs/venv_py3.6; {cmd}', universal_newlines=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1b0049e62a08> in <module>
#       1 # run the command
#       2
# ----> 3 x = subprocess.Popen(["/Users/avinash/anaconda3/envs/venv_py3.6/bin/python3.6", cmd])
#       4
#       5 # x = subprocess.check_output(cmd, universal_newlines=True)
#
# ~/anaconda3/envs/venv_py3.6/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ...

# %%
from tqdm import tqdm
